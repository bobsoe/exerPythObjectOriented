# %%
#video 1

# %%
class Employee:
    pass

emp_1 = Employee()
emp_2 = Employee()

print(emp_1)
print(emp_2)
# Out:
# <__main__.Employee object at 0x7f85e13deeb0>
# <__main__.Employee object at 0x7f85e13de910>

# %%
class Employee:
    pass

emp_1 = Employee()
emp_2 = Employee()

print(emp_1)
print(emp_2)

emp_1.first = 'Corey'
emp_1.last = 'Schafer'
emp_1.email = 'Corey.Schafer@company.com'
emp_1.pay = 500000

emp_2.first = 'Test'
emp_2.last = 'User'
emp_2.email = 'Test.User@company.com'
emp_2.pay = 600000

print(emp_1.email)
print(emp_2.email)
# Out:
# <__main__.Employee object at 0x7f85d016a4f0>
# <__main__.Employee object at 0x7f85d016a7c0>
# Corey.Schafer@company.com
# Test.User@company.com

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)

#print(emp_1)
#print(emp_2)




print(emp_1.email)
print(emp_2.email)
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)

#print(emp_1)
#print(emp_2)




print(emp_1.email)
print(emp_2.email)

print('{} {}'.format(emp_1.first, emp_1.last))
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com
# Correy Schaffer

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)

#print(emp_1)
#print(emp_2)




print(emp_1.email)
print(emp_2.email)

print(emp_1.fullname())
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com
# Correy Schaffer

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)

#print(emp_1)
#print(emp_2)




print(emp_1.email)
print(emp_2.email)

print(emp_1.fullname)
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com
# <bound method Employee.fullname of <__main__.Employee object at 0x7f85d016ac70>>

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)

#print(emp_1)
#print(emp_2)




print(emp_1.email)
print(emp_2.email)

print(emp_2.fullname())
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com
# Test User

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname():
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)





#print(emp_2.fullname())
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname():
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)



#print(emp_2.fullname())
# Out:
# Correy.Schaffer@company.com
# Test.User@company.com

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname():
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)



print(emp_2.fullname())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-21366fcd98ad> in <module>
#      15
#      16
# ---> 17 print(emp_2.fullname())
#
# TypeError: fullname() takes 0 positional arguments but 1 was given

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schaffer', 50000)
emp_2 = Employee('Test', 'User', 60000)



print(emp_2.fullname())
# Out:
# Test User

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


emp_1.fullname()
print(Employee.fullname(emp_1))
# Out:
# Correy Schaffer

# %%
#video2

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * 1.04)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(emp_1.pay)
emp_1.apply_raise
print(emp_1.pay)
# Out:
# 50000
# 50000

# %%
class Employee:
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * 1.04)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(emp_1.pay)
emp_1.apply_raise()
print(emp_1.pay)
# Out:
# 50000
# 52000

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(emp_1.pay)
emp_1.apply_raise()
print(emp_1.pay)

#emp_1.raise_amount
#Employee.raise_amount
# Out:
# 50000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-2bb3070b724a> in <module>
#      21
#      22 print(emp_1.pay)
# ---> 23 emp_1.apply_raise()
#      24 print(emp_1.pay)
#      25
#
# <ipython-input-23-2bb3070b724a> in apply_raise(self)
#      14
#      15     def apply_raise(self):
# ---> 16         self.pay = int(self.pay * raise_amount)
#      17
#      18
#
# NameError: name 'raise_amount' is not defined

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * Employee.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(emp_1.pay)
emp_1.apply_raise()
print(emp_1.pay)

#emp_1.raise_amount
#Employee.raise_amount
# Out:
# 50000
# 52000

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(emp_1.pay)
emp_1.apply_raise()
print(emp_1.pay)

#emp_1.raise_amount
#Employee.raise_amount
# Out:
# 50000
# 52000

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# 1.04
# 1.04
# 1.04

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(emp_1.__dict__)


#print(Employee.raise_amount)
#print(emp_1.raise_amount)
#print(emp_2.raise_amount)
# Out:
# {'first': 'Correy', 'last': 'Schafer', 'pay': 50000, 'email': 'Correy.Schafer@company.com'}

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(Employee.__dict__)


#print(Employee.raise_amount)
#print(emp_1.raise_amount)
#print(emp_2.raise_amount)
# Out:
# {'__module__': '__main__', 'raise_amount': 1.04, '__init__': <function Employee.__init__ at 0x7f85d01771f0>, 'fullname': <function Employee.fullname at 0x7f85d0177160>, 'apply_raise': <function Employee.apply_raise at 0x7f85d0177280>, '__dict__': <attribute '__dict__' of 'Employee' objects>, '__weakref__': <attribute '__weakref__' of 'Employee' objects>, '__doc__': None}

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

#print(Employee.__dict__)

Employee.raise_amount = 1.05

print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# 1.05
# 1.05
# 1.05

# %%
class Employee:
    
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)



emp_1.raise_amount = 1.05

print(emp_1.__dict__)

print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# {'first': 'Correy', 'last': 'Schafer', 'pay': 50000, 'email': 'Correy.Schafer@company.com', 'raise_amount': 1.05}
# 1.04
# 1.05
# 1.04

# %%
class Employee:
    
    num_of_emps = 0
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


print(Employee.num_of_emps)
# Out:
# 2

# %%
class Employee:
    
    num_of_emps = 0
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        

print(Employee.num_of_emps)        
        
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)
# Out:
# 0

# %%
#video3

# %%
class Employee:
    
    num_of_emps = 0
    raise_amount = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@company.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amount)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
      
        
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

print(Employee.raise_amount)
print(emp_1.raise_amount)
print(emp_2.raise_amount)
# Out:
# 1.04
# 1.04
# 1.04

# %%
class Employee:
    
    num_of_emps = 0
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
        
      
        
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

Employee.set_raise_amt(1.05)

print(Employee.raise_amt)
print(emp_1.raise_amt)
print(emp_2.raise_amt)
# Out:
# 1.05
# 1.05
# 1.05

# %%
class Employee:
    
    num_of_emps = 0
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
        
      
        
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)

emp_1.set_raise_amt(1.05)

print(Employee.raise_amt)
print(emp_1.raise_amt)
print(emp_2.raise_amt)
# Out:
# 1.05
# 1.05
# 1.05

# %%
class Employee:
    
    num_of_emps = 0
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
        
      
        
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


emp_str_1 = 'John-Doe-70000'
emp_str_2 = 'Steve-Smith-30000'
emp_str_3 = 'Jane-Doe-90000'

first, last, pay = emp_str_1.split('-')

new_emp_1 = Employee(first, last, pay)

#new_emp_1 = Employee.from_string(emp_str_1)

print(new_emp_1.email)
print(new_emp_1.pay)
# Out:
# John.Doe@email.com
# 70000

# %%
class Employee:
    
    num_of_emps = 0
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
        
    @classmethod
    def from_string(cls, emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first, last, pay)
    
      
        
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


emp_str_1 = 'John-Doe-70000'
emp_str_2 = 'Steve-Smith-30000'
emp_str_3 = 'Jane-Doe-90000'


new_emp_1 = Employee.from_string(emp_str_1)

print(new_emp_1.email)
print(new_emp_1.pay)
# Out:
# John.Doe@email.com
# 70000

# %%
class Employee:
    
    num_of_emps = 0
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
        
    @classmethod
    def from_string(cls, emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first, last, pay)
    
    @staticmethod
    def is_workday(day):
        if day.weekday() == 5 or day.weekday() == 6:
            return False
        return True
    
           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


import datetime
my_date = datetime.date(2016, 7, 10)

print(Employee.is_workday(my_date))
# Out:
# False

# %%
class Employee:
    
    num_of_emps = 0
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    @classmethod
    def set_raise_amt(cls, amount):
        cls.raise_amt = amount
        
    @classmethod
    def from_string(cls, emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first, last, pay)
    
    @staticmethod
    def is_workday(day):
        if day.weekday() == 5 or day.weekday() == 6:
            return False
        return True
    
           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'User', 60000)


import datetime
my_date = datetime.date(2016, 7, 11)

print(Employee.is_workday(my_date))
# Out:
# True

# %%
#video4

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    pass

           
dev_1 = Employee('Correy', 'Schafer', 50000)
dev_2 = Employee('Test', 'Employee', 60000)


print(help(Developer))

#print(dev_1.email)
#print(dev_2.email)
# Out:
# Help on class Developer in module __main__:
#
# class Developer(Employee)
#  |  Developer(first, last, pay)
#  |
#  |  Method resolution order:
#  |      Developer
#  |      Employee
#  |      builtins.object
#  |
#  |  Methods inherited from Employee:
#  |
#  |  __init__(self, first, last, pay)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  apply_raise(self)
#  |
#  |  fullname(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Employee:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Employee:
#  |
#  |  raise_amt = 1.04
#
# None

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    pass

           
dev_1 = Employee('Correy', 'Schafer', 50000)
dev_2 = Employee('Test', 'Employee', 60000)



#print(dev_1.email)
#print(dev_2.email)

print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)
# Out:
# 50000
# 52000

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    

           
dev_1 = Developer('Correy', 'Schafer', 50000)
dev_2 = Developer('Test', 'Employee', 60000)



#print(dev_1.email)
#print(dev_2.email)

print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)
# Out:
# 50000
# 55000

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    

           
dev_1 = Employee('Correy', 'Schafer', 50000)
dev_2 = Developer('Test', 'Employee', 60000)



#print(dev_1.email)
#print(dev_2.email)

print(dev_1.pay)
dev_1.apply_raise()
print(dev_1.pay)
# Out:
# 50000
# 52000

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')



print(dev_1.email)
print(dev_1.prog_lang)

#print(dev_1.pay)
#dev_1.apply_raise()
#print(dev_1.pay)
# Out:
# Correy.Schafer@email.com
# Python

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])

print(mgr_1.email)

#print(dev_1.email)
#print(dev_1.prog_lang)

#print(dev_1.pay)
#dev_1.apply_raise()
#print(dev_1.pay)
# Out:
# Sue.Smith@email.com

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])

print(mgr_1.email)

mgr_1.print_emps()

#print(dev_1.email)
#print(dev_1.prog_lang)

#print(dev_1.pay)
#dev_1.apply_raise()
#print(dev_1.pay)
# Out:
# Sue.Smith@email.com
# --> Correy Schafer

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])

print(mgr_1.email)

mgr_1.add_emp(dev_2)

mgr_1.print_emps()

#print(dev_1.email)
#print(dev_1.prog_lang)

#print(dev_1.pay)
#dev_1.apply_raise()
#print(dev_1.pay)
# Out:
# Sue.Smith@email.com
# --> Correy Schafer
# --> Test Employee

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])

print(mgr_1.email)

mgr_1.add_emp(dev_2)
mgr_1.remove_emp(dev_1)

mgr_1.print_emps()

#print(dev_1.email)
#print(dev_1.prog_lang)

#print(dev_1.pay)
#dev_1.apply_raise()
#print(dev_1.pay)
# Out:
# Sue.Smith@email.com
# --> Test Employee

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])


print(isinstance(mgr_1, Manager))
# Out:
# True

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])


print(isinstance(mgr_1, Employee))
# Out:
# True

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])


print(isinstance(mgr_1, Developer))
# Out:
# False

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])


print(issubclass(Developer, Employee))
# Out:
# True

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])


print(issubclass(Manager, Employee))
# Out:
# True

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
 

class Developer(Employee):
    raise_amt = 1.1
    def __init__(self, first, last, pay, prog_lang):
        super().__init__(first, last, pay)
        self.prog_lang = prog_lang
        
        
class Manager(Employee):
    
    def __init__(self, first, last, pay, employees=None):
        super().__init__(first, last, pay)
        if employees is None:
            self.employees = []
        else: 
            self.employees = employees
        
        
    def add_emp(self, emp):
        if emp not in self.employees:
            self.employees.append(emp)
      
    def remove_emp(self, emp):
        if emp in self.employees:
            self.employees.remove(emp)
            
    def print_emps(self):
        for emp in self.employees:
            print('-->', emp.fullname())
    
    

           
dev_1 = Developer('Correy', 'Schafer', 50000, 'Python')
dev_2 = Developer('Test', 'Employee', 60000, 'Java')

mgr_1 = Manager('Sue', 'Smith', 90000, [dev_1])


print(issubclass(Manager, Developer))
# Out:
# False

# %%
#video5

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



print(1 + 2)
print('a' + 'b')
# Out:
# 3
# ab

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



print(emp_1)
# Out:
# <__main__.Employee object at 0x7f85d01c3c10>

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
   # def __str__(self):
   #     pass

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



print(emp_1)

#repr(emp_1)
#str(emp_1)
# Out:
# Employee('Correy', 'Schafer', '50000')

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



print(emp_1)

#repr(emp_1)
#str(emp_1)
# Out:
# Correy Schafer - Correy.Schafer@email.com

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



#print(emp_1)

print(repr(emp_1))
print(str(emp_1))
# Out:
# Employee('Correy', 'Schafer', '50000')
# Correy Schafer - Correy.Schafer@email.com

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



#print(emp_1)

print(emp_1.__repr__())
print(emp_1.__str__())
# Out:
# Employee('Correy', 'Schafer', '50000')
# Correy Schafer - Correy.Schafer@email.com

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))

print(1+2)
# Out:
# 3

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))

print(1+2)

print(int.__add__(1, 2))
# Out:
# 3
# 3

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)



#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))

print(1+2)

print(int.__add__(1, 2))
print(str.__add__('a', 'b'))
# Out:
# 3
# 3
# ab

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)
    
    def __add__(self, other):
        return self.pay + other.pay

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)

print(emp_1 + emp_2)

#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))
# Out:
# 110000

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)
    
    #def __add__(self, other):
    #    return self.pay + other.pay

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)

print(emp_1 + emp_2)

#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-49aa2cb3d396> in <module>
#      30 emp_2 = Employee('Test', 'Employee', 60000)
#      31
# ---> 32 print(emp_1 + emp_2)
#      33
#      34 #print(emp_1)
#
# TypeError: unsupported operand type(s) for +: 'Employee' and 'Employee'

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)
    
    def __add__(self, other):
        return self.pay + other.pay

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)

print(emp_1 + emp_2)

#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))
# Out:
# 110000

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)
    
    def __add__(self, other):
        return self.pay + other.pay

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)


print(len('test'))


#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))
# Out:
# 4

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)
    
    def __add__(self, other):
        return self.pay + other.pay

           
emp_1 = Employee('Correy', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)


print(len('test'))

print('test'.__len__())


#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))
# Out:
# 4
# 4

# %%
class Employee:
    
    raise_amt = 1.04
    
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.pay = pay
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
        
    def __repr__(self):
        return "Employee('{}', '{}', '{}')".format(self.first, self.last, self.pay)
    
    
    def __str__(self):
        return  '{} - {}'.format(self.fullname(), self.email)
    
    def __add__(self, other):
        return self.pay + other.pay
    
    def __len__(self):
        return len(self.fullname())

           
emp_1 = Employee('Corey', 'Schafer', 50000)
emp_2 = Employee('Test', 'Employee', 60000)


print(len(emp_1))




#print(emp_1)

#print(repr(emp_1))
#print(str(emp_1))
# Out:
# 13

# %%
#video6

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname())
# Out:
# John
# John.Smith@email.com
# John Smith

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
        self.email = first + '.' + last + '@email.com'
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

emp_1.first = "Jim"

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname())
# Out:
# Jim
# John.Smith@email.com
# Jim Smith

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
        
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

emp_1.first = "Jim"

print(emp_1.first)
print(emp_1.email())
print(emp_1.fullname())
# Out:
# Jim
# Jim.Smith@email.com
# Jim Smith

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
    
    @property    
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

emp_1.first = "Jim"

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname())
# Out:
# Jim
# Jim.Smith@email.com
# Jim Smith

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
    
    @property    
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

emp_1.first = "Jim"

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)
# Out:
# Jim
# Jim.Smith@email.com
# Jim Smith

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
    
    @property    
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

emp_1.fullname = 'Corey Schafer'

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-b6a8c05f9ab9> in <module>
#      19 emp_1 = Employee('John', 'Smith')
#      20
# ---> 21 emp_1.fullname = 'Corey Schafer'
#      22
#      23 print(emp_1.first)
#
# AttributeError: can't set attribute

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
    
    @property    
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    


           
emp_1 = Employee('John', 'Smith')

#emp_1.fullname = 'Corey Schafer'

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)
# Out:
# John
# John.Smith@email.com
# John Smith

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
    
    @property    
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    @fullname.setter
    def fullname(self, name):
        first, last = name.split(' ')
        self.first = first
        self.last = last

           
emp_1 = Employee('John', 'Smith')

emp_1.fullname = 'Corey Schafer'

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)
# Out:
# Corey
# Corey.Schafer@email.com
# Corey Schafer

# %%
class Employee:
    
    
    def __init__(self, first, last):
        self.first = first
        self.last = last
    
    @property    
    def email(self):
        return '{}.{}@email.com'.format(self.first, self.last)
        
    @property
    def fullname(self):
        return '{} {}'.format(self.first, self.last)
    
    @fullname.setter
    def fullname(self, name):
        first, last = name.split(' ')
        self.first = first
        self.last = last

        
    @fullname.deleter
    def fullname(self):
        print('Delete Name!')
        self.first = None
        self.last = None
        
           
emp_1 = Employee('John', 'Smith')

emp_1.fullname = 'Corey Schafer'

print(emp_1.first)
print(emp_1.email)
print(emp_1.fullname)

del emp_1.fullname
# Out:
# Corey
# Corey.Schafer@email.com
# Corey Schafer
# Delete Name!
